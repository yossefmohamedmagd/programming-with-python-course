# %%
print(5>5)
# Out:
# False

# %%
x=('math','electricity','it')
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={'arabic','english','technology'}
print(type(x))
# Out:
# <class 'set'>

# %%
print(x)
# Out:
# {'arabic', 'technology', 'english'}

# %%
x={'arabic','english','technology','arabic'}
print(x)
# Out:
# {'arabic', 'technology', 'english'}

# %%
y={'name':'john','school':'weschool','grade':'2'}
print(y)
# Out:
# {'name': 'john', 'school': 'weschool', 'grade': '2'}

# %%
print(y.items())
# Out:
# dict_items([('name', 'john'), ('school', 'weschool'), ('grade', '2')])

# %%
print(y.keys())
# Out:
# dict_keys(['name', 'school', 'grade'])

# %%
print(y.values())
# Out:
# dict_values(['john', 'weschool', '2'])

# %%
print(y['name'])
# Out:
# john

# %%
print(y['school'])
# Out:
# weschool

# %%
z={'name':['john','mark','sally'],'school':'weschool'}
print(z)
# Out:
# {'name': ['john', 'mark', 'sally'], 'school': 'weschool'}

# %%
print(z['school'])
# Out:
# weschool

# %%
print(z['name'])
# Out:
# ['john', 'mark', 'sally']

# %%
x=10
y=35
if(x>y):
    print('x is greater than y')
elif(x==y):
    print('x is equal y')
else:
    print("x is less than y")
# Out:
# x is less than y

# %%
a=float(input("enter number"))
# Out:
# enter number 5

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
a=float(input("enter number"))
if(a>0):
    print("positive")
elif(a==0): 
    print("zero")
else:
    print("negative")
# Out:
# enter number 12
# positive

# %%
o=1
while(o<6):
    print(o)
    o=o+1
# Out:
# 1
# 2
# 3
# 4
# 5

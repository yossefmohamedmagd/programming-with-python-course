# %%
print("hallo")
# Out:
# hallo

# %%
x=5
y=2
print(x+y)
# Out:
# 7

# %%
x,y,z=1,2,3

# %%
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x="youssef"
print(x+"magd")
# Out:
# youssefmagd

# %%
text="youssef magd yuio"
len(text)
# Out:
# 17

# %%
print("magd"in text)
# Out:
# True

# %%
print(text.upper())
# Out:
# YOUSSEF MAGD YUIO

# %%
x="camb"
y="python"
z=4
print("future{},{},groub{}".format(x,y,z))
# Out:
# futurecamb,python,groub4

# %% [markdown]
# print(o)

# %%
print(5*2)
# Out:
# 10

# %%
print(10/2)
# Out:
# 5.0

# %%
print(5%2)
# Out:
# 1

# %%
print(5+3/2*(3-1))
# Out:
# 8.0

# %%
x=5
y=6.5
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
y=int(2.8)
print(y)
# Out:
# 2

# %%
x=float(2)
print(x)
# Out:
# 2.0

# %%
z=str(5)
print(z)
# Out:
# 5

# %%
print(type(z))
# Out:
# <class 'str'>

# %%
name=input("type your name")
# Out:
# type your name youssef magd

# %%
print(name)
# Out:
# youssef magd

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
x=input("type a number")
# Out:
# type a number 25517789

# %%
print(x)
# Out:
# 25517789

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
z=int(x)

# %%
print(z)
# Out:
# 25517789

# %%
print(z+1)
# Out:
# 25517790

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
x="false"
print(type(x))
# Out:
# <class 'str'>

# %%
x={5,9}
print(x)
# Out:
# {9, 5}

# %%
x=["math","it","phisics","electricity"]
print(x)
# Out:
# ['math', 'it', 'phisics', 'electricity']

# %%
print(x[0])
# Out:
# math

# %%
print(x[3])
# Out:
# electricity

# %%
print(x[-3])
# Out:
# it

# %%
print(x[1:4])
# Out:
# ['it', 'phisics', 'electricity']

# %%
print(x[0:3])
# Out:
# ['math', 'it', 'phisics']

# %%
x[2]='communication'
print(x)
# Out:
# ['math', 'it', 'communication', 'electricity']

# %%
y=input('')
# Out:
#  bio

# %%
x[2]=y

# %%
print(x)
# Out:
# ['math', 'it', 'bio', 'electricity']

# %%
x.append("arabic")
print(x)
# Out:
# ['math', 'it', 'bio', 'electricity', 'arabic']

# %%
x.insert(1,"social skills")
print(x)
# Out:
# ['math', 'social skills', 'it', 'bio', 'electricity', 'arabic']

# %%
x.remove('math')
print(x)
# Out:
# ['social skills', 'it', 'electricity', 'arabic']
